# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas
dataset_DF = pandas.read_csv("/content/drive/MyDrive/SI_AI_KBS/integrazione_AlBERTo_WMAL/sentipolc_agritrend/data/creagritrend_processed.csv")
print(dataset_DF)
print("colonne:   ")
dataset_DF
# Out:
#      Unnamed: 0  ...                                              clean
# 0             0  ...  <user> <hashtag> riso </hashtag> procedura per...
# 1             1  ...  <user> gelate xylella sblocco psr a <hashtag> ...
# 2             2  ...  <user> <user> <hashtag> gilet arancio ni </has...
# 3             3  ...  <user> uova timbratura all origine necessaria ...
# 4             4  ...  <user> <user> / sicurezza alimentare e sostanz...
# ..          ...  ...                                                ...
# 981         995  ...  my week on twitter 🎉 <number> mentions <number...
# 982         996  ...  <hashtag> tradizione </hashtag> torna protagon...
# 983         997  ...  clima coldiretti il natale bollente con temper...
# 984         998  ...  usa ue <user> possibili nuovi <hashtag> dazi <...
# 985         999  ...  capodanno coldiretti le feste di fine anno fan...
#
# [986 rows x 12 columns]
# colonne:
#      Unnamed: 0  ...                                              clean
# 0             0  ...  <user> <hashtag> riso </hashtag> procedura per...
# 1             1  ...  <user> gelate xylella sblocco psr a <hashtag> ...
# 2             2  ...  <user> <user> <hashtag> gilet arancio ni </has...
# 3             3  ...  <user> uova timbratura all origine necessaria ...
# 4             4  ...  <user> <user> / sicurezza alimentare e sostanz...
# ..          ...  ...                                                ...
# 981         995  ...  my week on twitter 🎉 <number> mentions <number...
# 982         996  ...  <hashtag> tradizione </hashtag> torna protagon...
# 983         997  ...  clima coldiretti il natale bollente con temper...
# 984         998  ...  usa ue <user> possibili nuovi <hashtag> dazi <...
# 985         999  ...  capodanno coldiretti le feste di fine anno fan...
#
# [986 rows x 12 columns]

# %%
import time
dataset_reduced = dataset_DF
start_time = time.time()
lista_text_tokenized = []
lista_lunghezze = []
i = 0 #per tenere conto dell'indice del plot
over_128 = 0 #conteggio dei plots che superano i 512 tokens

for text in dataset_reduced["text_clean"]:
  i+=1
  marked_text=text.lower()
  tokenized_text = marked_text.split(" ")
  #print(tokenized_text)
  lista_text_tokenized.append(tokenized_text)
  lunghezza = len(tokenized_text)
  lista_lunghezze.append(lunghezza)
  #stampiamo solo i plots che eccedono nella lunghezza massima, pari a 512
  if (i%100)==0:
    print(str(i) + " text tokenizzati")

print(lista_text_tokenized)
# Out:
# 100 text tokenizzati
# 200 text tokenizzati
# 300 text tokenizzati
# 400 text tokenizzati
# 500 text tokenizzati
# 600 text tokenizzati
# 700 text tokenizzati
# 800 text tokenizzati
# 900 text tokenizzati
# [['procedura', 'ripristino', 'dazi', 'rush', 'finale', 'regolamento', 'ue', 'previsto', 'gennaio'], ['gelate', 'xylella', 'sblocco', 'psr', 'invasione', 'video', 'portavoce', 'spagnoletti', 'zeuli'], ['confeuro', 'protesta', 'giusta', 'serve', 'coerenza', 'assunzione', 'responsabilità'], ['uova', 'timbratura', 'origine', 'necessaria', 'tutelare', 'consumatori', 'filiera', 'made', 'italy'], ['sicurezza', 'alimentare', 'sostanze', 'chimiche', 'sistema', 'ue', 'sottoposto', 'forti', 'pressioni', 'corte', 'conti', 'europea', 'incongruenze', 'problematiche'], ['indicazioni', 'geografiche', 'vera', 'tutela', 'solo', 'accordi', 'internazionali', 'europa', 'tema', 'interessa', 'solo', 'paesi'], ['disponibile', 'catalogo', 'rafforza', 'ulteriormente', 'offerta', 'sementi', 'agrofarmaci', 'tecnologie', 'meglio', 'rispondere', 'sfide', 'agricoltura'], ['celebrazioni', 'piazza', 'san', 'pietro'], ['gusto', 'sapori', 'inverno', 'profumo', 'zucca', 'porri'], ['uova', 'allevate', 'gabbia', 'natura', 'ecco', 'prezzi', 'settimana', 'stilati', 'borsa', 'merci', 'telematica'], ['appello', 'consorzio', 'chianti', 'iniziamo', 'coraggio', 'sperimentazione', 'campo', 'viti', 'resistenti', 'funghi'], ['agenda', 'prossimi', 'giorni', 'dettagli'], ['obbligo', 'prodotti', 'alimentari', 'centinaio', 'vince', 'made', 'italy', 'tutele', 'produttori', 'onesti', 'consumatori'], ['xylella', 'italia', 'olivicola', 'denuncia', 'procura', 'roma', 'parlamentari', 'negazionisti', 'm', 's'], ['governo', 'segue', 'partecipa', 'attenzione', 'perchè', 'impone', 'articolo', 'costituzione', 'afferma', 'presidente', 'consiglio', 'conte', 'stati', 'generali', 'cooperazione', 'italiana'], ['remaschi', 'assessore', 'agricoltura', 'sempre', 'creduto', 'ig', 'percorso', 'crescita', 'globale', 'coinvolga', 'attori', 'filiera'], ['olivicoltori', 'governo', 'incontro', 'febbraio', 'nuova', 'fiera', 'levante', 'bari'], ['dichiarazioni', 'centinaio', 'ddl'], ['indicazioni', 'geografiche', 'ecco', 'proposte', 'strategiche', 'istituzioni', 'nazionali', 'internazionali', 'meeting', 'qualivita'], ['lavora', 'trovare', 'soluzione'], ['capacitybuilding', 'bandi', 'video', 'integrali', 'incontri', 'divisi', 'temi', 'interventi', 'info', 'suggerimenti', 'preparazione', 'progetti', 'settori', 'risorse', 'idriche', 'scadenze', 'bandi'], ['olio', 'xylella', 'due', 'decreti', 'd', 'urgenza', 'promessi', 'davanti', 'mila', 'olivicoltori', 'piazza', 'roma'], ['benvenuto', 'brunello', 'celebra', 'alex', 'zanardi', 'firma', 'piastrella', 'vendemmia', 'stelle'], ['crisi', 'latte', 'ovino', 'centinaio', 'passi', 'avanti', 'punti', 'concordati', 'uscire', 'crisi', 'prezzo', 'tavolo', 'tecnico', 'prefettura', 'sassari'], ['cun', 'conigli', 'grasso', 'strutti', 'tagli', 'carne', 'suina', 'fresca', 'prezzi', 'settimana', 'febbraio'], ['incrementare', 'produttività', 'futuro', 'agricoltura', 'punto', 'ettore', 'cantù', 'società', 'agraria', 'lombardia'], ['etichettatura', 'obbligatoria', 'conferenza', 'stampa', 'centinaio', 'nuove', 'norme', 'marzo'], ['regione', 'liguria', 'psr', 'misura', 'investimenti', 'creazione', 'sviluppo', 'attività', 'extra', 'agricole'], ['agricola', 'spetta', 'titolare', 'partita', 'iva'], ['elettroniche', 'imposta', 'bollo', 'sfugge', 'fisco'], ['ora', 'iniziamo', 'lavorare', 'agricoltura', 'turismo'], ['nuova', 'moratoria', 'mutui', 'imprese', 'agricole'], ['new', 'report', 'sub', 'saharan', 'has', 'the', 'highest', 'rate', 'of', 'female', 'entrepreneurship', 'the', 'world', 'here', 's', 'how', 'countries', 'can', 'help', 'them', 'grow'], ['consorzio', 'tutela', 'igp', 'aurora', 'casillo', 'nuovo', 'presidente'], ['made', 'italy', 'positivo', 'secondo', 'incombe', 'spettro', 'no', 'deal'], ['avvicina', 'lavora'], ['salvini', 'confcooperative', 'soluzione', 'africa', 'buona', 'cooperazione', 'loco', 'rispettando', 'culture', 'guardiania', 'mari'], ['alleanza', 'coop', 'costa', 'crociere', 'promuove', 'romano', 'dop', 'ammiraglia', 'costa', 'diadema'], ['appello', 'governo',  ...

# %%
#Load WMAL
import pandas
wmal = pandas.read_csv("/content/drive/MyDrive/SI_AI_KBS/integrazione_AlBERTo_WMAL/sentipolc_agritrend/data/CREAGRITREND_WMAL.csv")
wmal_sent = pandas.read_csv("/content/drive/MyDrive/SI_AI_KBS/integrazione_AlBERTo_WMAL/sentipolc_agritrend/data/SENTIPOLC_WMAL.csv")

# %%
wmal_dic ={}

for index, item in wmal_sent.iterrows():
  wmal_dic[item["words"]] = item["value"]

for index, item in wmal.iterrows():
  wmal_dic[item["words"]] = item["value"]

# %%
words = []
values = []

for key, item in wmal_dic.items():
  words.append(key)
  values.append(item)

# %%
len(words)
# Out:
# 8266

# %%
#Create matrix
import numpy as np
wmal_matrix = []
for tokenized_plot in lista_text_tokenized:

  sentence_vec = np.zeros([8266])
  for tok in tokenized_plot:
    try:
      indice = words.index(tok)
      sentence_vec[indice]= wmal_dic[tok]
    except:
      pass
  wmal_matrix.append(sentence_vec)

# %%
wmal_matrix=np.array(wmal_matrix)
wmal_matrix.shape
for a in wmal_matrix[1]:
  if a !=0:
    print(a)
# Out:
# -0.5516282

# %%
import joblib
joblib.dump(wmal_matrix,"/content/drive/MyDrive/SI_AI_KBS/integrazione_AlBERTo_WMAL/sentipolc_agritrend/support_files/dictionary_agritrend_8266.joblib")
#joblib.dump(lista_text_tokenized,"/content/drive/MyDrive/SI_AI_KBS/integrazione_AlBERTo_WMAL/sentipolc_agritrend/data/agritrend_tokenized.joblib")
# Out:
# ['/content/drive/MyDrive/SI_AI_KBS/integrazione_AlBERTo_WMAL/sentipolc_agritrend/support_files/dictionary_agritrend_8266.joblib']
